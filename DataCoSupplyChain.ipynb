# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/drive/MyDrive/DataCoSupplyChainDataset.csv', encoding='unicode_escape')
df.head()
# Out:
#        Type  ...   Shipping Mode
# 0     DEBIT  ...  Standard Class
# 1  TRANSFER  ...  Standard Class
# 2      CASH  ...  Standard Class
# 3     DEBIT  ...  Standard Class
# 4   PAYMENT  ...  Standard Class
#
# [5 rows x 53 columns]

# %%
df1=df[['Order Country','Order City','Order Status']]
df1.head(100)
# Out:
#            Order Country     Order City     Order Status
# 0              Indonesia         Bekasi         COMPLETE
# 1                  India        Bikaner          PENDING
# 2                  India        Bikaner           CLOSED
# 3              Australia     Townsville         COMPLETE
# 4              Australia     Townsville  PENDING_PAYMENT
# ..                   ...            ...              ...
# 95                Brasil        Barueri          PENDING
# 96                Brasil      Arapongas          PENDING
# 97                  Cuba       Camagüey          PENDING
# 98                  Cuba      Las Tunas          PENDING
# 99  República Dominicana  Santo Domingo          PENDING
#
# [100 rows x 3 columns]

# %% [markdown]
# QUESTION 1 END SOLUTION QUESTION 2 START SOLUTION-->

# %%
df2=df[['Order Country','Order Status']]
df2.head(100)
# Out:
#            Order Country     Order Status
# 0              Indonesia         COMPLETE
# 1                  India          PENDING
# 2                  India           CLOSED
# 3              Australia         COMPLETE
# 4              Australia  PENDING_PAYMENT
# ..                   ...              ...
# 95                Brasil          PENDING
# 96                Brasil          PENDING
# 97                  Cuba          PENDING
# 98                  Cuba          PENDING
# 99  República Dominicana          PENDING
#
# [100 rows x 2 columns]

# %%
df1[(df1['Order Country']=='India') & (df['Order Status']=='PENDING')].head(10000)
# Out:
#        Order Country   Order City Order Status
# 1              India      Bikaner      PENDING
# 21             India     Jabalpur      PENDING
# 45             India    Bangalore      PENDING
# 46             India    Bangalore      PENDING
# 382            India         Pune      PENDING
# ...              ...          ...          ...
# 180142         India  Bhubaneswar      PENDING
# 180164         India         Agra      PENDING
# 180248         India        Dewas      PENDING
# 180331         India        Ajmer      PENDING
# 180405         India        Patna      PENDING
#
# [537 rows x 3 columns]

# %%
df2[(df2['Order Status']=='SUSPECTED_FRAUD')].head(100)
# Out:
#        Order Country     Order Status
# 10             Japón  SUSPECTED_FRAUD
# 24         Australia  SUSPECTED_FRAUD
# 183   Estados Unidos  SUSPECTED_FRAUD
# 184   Estados Unidos  SUSPECTED_FRAUD
# 185   Estados Unidos  SUSPECTED_FRAUD
# ...              ...              ...
# 1965  Estados Unidos  SUSPECTED_FRAUD
# 1966  Estados Unidos  SUSPECTED_FRAUD
# 1967  Estados Unidos  SUSPECTED_FRAUD
# 1968  Estados Unidos  SUSPECTED_FRAUD
# 1969  Estados Unidos  SUSPECTED_FRAUD
#
# [100 rows x 2 columns]

# %%
df2['Order Country'].value_counts().idxmax()
# Out:
# 'Estados Unidos'

# %% [markdown]
# QUESTION 2 END SOLUTION QUESTION 5 START SOLUTION-->

# %%
df5=df[['Days for shipping (real)','Days for shipment (scheduled)','Order Status']]
df5.head(100)
# Out:
#     Days for shipping (real)  Days for shipment (scheduled)     Order Status
# 0                          3                              4         COMPLETE
# 1                          5                              4          PENDING
# 2                          4                              4           CLOSED
# 3                          3                              4         COMPLETE
# 4                          2                              4  PENDING_PAYMENT
# ..                       ...                            ...              ...
# 95                         2                              4          PENDING
# 96                         6                              4          PENDING
# 97                         2                              4          PENDING
# 98                         3                              4          PENDING
# 99                         5                              4          PENDING
#
# [100 rows x 3 columns]

# %%
df6=df5[(df5['Days for shipping (real)'] > df5['Days for shipment (scheduled)']) & (df5['Order Status']=="COMPLETE")]
df6.head()
# Out:
#     Days for shipping (real)  Days for shipment (scheduled) Order Status
# 6                          2                              1     COMPLETE
# 13                         2                              1     COMPLETE
# 15                         2                              1     COMPLETE
# 18                         2                              1     COMPLETE
# 25                         6                              2     COMPLETE

# %%
total_rows=len(df6.axes[0])
total_rows
# Out:
# 34199

# %% [markdown]
# QUESTION 5 END SOLUTION QUESTION 3 START SOLUTION-->

# %%
df7=df[['Product Name','Order Item Discount']]
df7.head(100)
# Out:
#                                      Product Name  Order Item Discount
# 0                                    Smart watch             13.110000
# 1                                    Smart watch             16.389999
# 2                                    Smart watch             18.030001
# 3                                    Smart watch             22.940001
# 4                                    Smart watch             29.500000
# ..                                            ...                  ...
# 95           Nike Men's Dri-FIT Victory Golf Polo            13.750000
# 96           Nike Men's Dri-FIT Victory Golf Polo            13.750000
# 97        Columbia Men's PFG Anchor Tough T-Shirt            13.500000
# 98  Under Armour Girls' Toddler Spine Surge Runni            18.000000
# 99           Nike Men's Dri-FIT Victory Golf Polo            25.000000
#
# [100 rows x 2 columns]

# %%
max_value=df7['Order Item Discount'].max()
max_value
# Out:
# 500.0

# %%
df8 = df7[(df7['Order Item Discount'] == max_value)]
df8.head()
# Out:
#               Product Name  Order Item Discount
# 12606  SOLE E35 Elliptical                500.0

# %% [markdown]
# QUESTION 3 END SOLUTION QUESTION 4 START SOLUTION -->

# %%
df9 = df[['Product Name','Sales','shipping date (DateOrders)']]
df9.head()
# Out:
#    Product Name   Sales shipping date (DateOrders)
# 0  Smart watch   327.75             2/3/2018 22:56
# 1  Smart watch   327.75            1/18/2018 12:27
# 2  Smart watch   327.75            1/17/2018 12:06
# 3  Smart watch   327.75            1/16/2018 11:45
# 4  Smart watch   327.75            1/15/2018 11:24

# %%
df10= df9.astype(str)
df10= df9[df9['Product Name'].apply(lambda x: x.split()[0]) == 'Nike']
df10.head()
# Out:
#                             Product Name       Sales shipping date (DateOrders)
# 50  Nike Men's Dri-FIT Victory Golf Polo  100.000000              4/5/2016 4:37
# 52  Nike Men's Dri-FIT Victory Golf Polo  100.000000             12/1/2016 1:18
# 53  Nike Men's Dri-FIT Victory Golf Polo  100.000000             1/5/2017 15:47
# 54  Nike Men's Dri-FIT Victory Golf Polo  100.000000            10/31/2015 6:24
# 59     Nike Men's Free 5.0+ Running Shoe  299.970001            10/6/2016 22:55

# %%
min = df10['Sales'].min()

# %%
df11= df10[(df10['Sales'] == min)]
df11.head()
# Out:
#                        Product Name  Sales shipping date (DateOrders)
# 2571  Nike Dri-FIT Crew Sock 6 Pack   22.0            4/17/2017 16:57
# 2575  Nike Dri-FIT Crew Sock 6 Pack   22.0            3/27/2017 12:10
# 2576  Nike Dri-FIT Crew Sock 6 Pack   22.0             3/24/2017 2:53
# 2587  Nike Dri-FIT Crew Sock 6 Pack   22.0            2/24/2017 22:33
# 2591  Nike Dri-FIT Crew Sock 6 Pack   22.0             2/15/2017 5:45

# %%
df11['year'] = df11['shipping date (DateOrders)'].apply(lambda x: x.split('/')[2])
df11['year'] = df11['year'].apply(lambda x: x.split(' ')[0])
df11
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                        Product Name  Sales shipping date (DateOrders)  year
# 2571  Nike Dri-FIT Crew Sock 6 Pack   22.0            4/17/2017 16:57  2017
# ...

# %%
df11['year'].value_counts().idxmin()
# Out:
# '2017'

# %% [markdown]
# QUESTION 4 END SOLUTION
