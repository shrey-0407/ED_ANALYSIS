# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/fandango_scrape.csv")

# %%
df.head()
# Out:
#                           FILM  STARS  RATING  VOTES
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1        Jurassic World (2015)    4.5     4.5  34390
# 2       American Sniper (2015)    5.0     4.8  34085
# 3             Furious 7 (2015)    5.0     4.8  33538
# 4            Inside Out (2015)    4.5     4.5  15749

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FILM    510 non-null    object
#  1   STARS   510 non-null    float64
#  2   RATING  510 non-null    float64
#  3   VOTES   510 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 16.1+ KB

# %%
df.describe()
# Out:
#             STARS      RATING         VOTES
# count  510.000000  510.000000    510.000000
# mean     3.532353    3.351765   1134.364706
# std      1.585616    1.512628   3809.952176
# min      0.000000    0.000000      0.000000
# 25%      3.500000    3.025000      2.000000
# 50%      4.000000    3.800000     17.500000
# 75%      4.500000    4.300000    183.500000
# max      5.000000    5.000000  34846.000000

# %%
plt.figure(figsize=(10,4),dpi=150)
sns.scatterplot(data=df,y='VOTES',x='RATING')

# %%
df.corr()
# Out:
#            STARS    RATING     VOTES
# STARS   1.000000  0.994870  0.165774
# RATING  0.994870  1.000000  0.165147
# VOTES   0.165774  0.165147  1.000000

# %% [markdown]
# ##CREATE A NEW COLUMN "YEAR"

# %%
title='Film Title Name (Year)'

# %%
title.split('(')[-1].replace(')','')
# Out:
# 'Year'

# %%
df['YEAR']=df['FILM'].apply(lambda title:title.split('(')[-1].replace(')',''))

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-415e77db6a13> in <module>()
# ----> 1 df.drop('Year',axis=1)
#       2 df
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
df['YEAR'].value_counts()
# Out:
# 2015    478
# 2014     23
# 1         7
# 1964      1
# 2016      1
# Name: YEAR, dtype: int64

# %%
sns.countplot(data=df,x='YEAR')

# %% [markdown]
# ##HIGHEST NUMBER OF VOTES

# %%
df.nlargest(10,'VOTES')
# Out:
#                                                FILM  STARS  RATING  VOTES  YEAR
# 0                       Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                             Jurassic World (2015)    4.5     4.5  34390  2015
# 2                            American Sniper (2015)    5.0     4.8  34085  2015
# 3                                  Furious 7 (2015)    5.0     4.8  33538  2015
# 4                                 Inside Out (2015)    4.5     4.5  15749  2015
# 5  The Hobbit: The Battle of the Five Armies (2014)    4.5     4.3  15337  2014
# 6               Kingsman: The Secret Service (2015)    4.5     4.2  15205  2015
# 7                                    Minions (2015)    4.0     4.0  14998  2015
# 8                    Avengers: Age of Ultron (2015)    5.0     4.5  14846  2015
# 9                             Into the Woods (2014)    3.5     3.4  13055  2014

# %%
len(df[df['VOTES']==0])
# Out:
# 73

# %%
fan_review=df[df['VOTES']>0]

# %%
sns.kdeplot(data=fan_review,x='RATING',clip=[0,5],fill=True,label='TRUE RATING')
sns.kdeplot(data=fan_review,x='STARS',clip=[0,5],fill=True,label='STARS RATING')
plt.legend(loc=(1.05,0.5))

# %%
fan_review['STARS_DIFF']=fan_review['STARS']-fan_review['RATING']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
fan_review
# Out:
#                             FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF
# 0    Fifty Shades of Grey (2015)    4.0     3.9  34846  2015         0.1
# 1          Jurassic World (2015)    4.5     4.5  34390  2015         0.0
# 2         American Sniper (2015)    5.0     4.8  34085  2015         0.2
# 3               Furious 7 (2015)    5.0     4.8  33538  2015         0.2
# 4              Inside Out (2015)    4.5     4.5  15749  2015         0.0
# ..                           ...    ...     ...    ...   ...         ...
# 432       That Sugar Film (2015)    5.0     5.0      1  2015         0.0
# 433            The Intern (2015)    5.0     5.0      1  2015         0.0
# 434        The Park Bench (2015)    5.0     5.0      1  2015         0.0
# 435         The Wanted 18 (2015)    5.0     5.0      1  2015         0.0
# 436       Z For Zachariah (2015)    5.0     5.0      1  2015         0.0
#
# [437 rows x 6 columns]

# %%
plt.figure(figsize=(12,4),dpi=150)
sns.countplot(data=fan_review,x='STARS_DIFF',palette='magma')

# %%
fan_review[fan_review['STARS_DIFF']==1]
# Out:
#                  FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF
# 381  Turbo Kid (2015)    5.0     4.0      2  2015         1.0

# %% [markdown]
# ##COMARSION OF FANDANGO RATINGS TO OTHER SITES

# %%
all_sites=pd.read_csv("/content/fandango_score_comparison.csv")

# %%
all_sites.head()
# Out:
#                              FILM  ...  Fandango_Difference
# 0  Avengers: Age of Ultron (2015)  ...                  0.5
# 1               Cinderella (2015)  ...                  0.5
# 2                  Ant-Man (2015)  ...                  0.5
# 3          Do You Believe? (2015)  ...                  0.5
# 4   Hot Tub Time Machine 2 (2015)  ...                  0.5
#
# [5 rows x 22 columns]

# %%
all_sites.describe()
# Out:
#        RottenTomatoes  RottenTomatoes_User  ...  Fandango_votes  Fandango_Difference
# count      146.000000           146.000000  ...      146.000000           146.000000
# mean        60.849315            63.876712  ...     3848.787671             0.243836
# std         30.168799            20.024430  ...     6357.778617             0.152665
# min          5.000000            20.000000  ...       35.000000             0.000000
# 25%         31.250000            50.000000  ...      222.250000             0.100000
# 50%         63.500000            66.500000  ...     1446.000000             0.200000
# 75%         89.000000            81.000000  ...     4439.500000             0.400000
# max        100.000000            94.000000  ...    34846.000000             0.500000
#
# [8 rows x 21 columns]

# %% [markdown]
# ##ROTTEN TOMATOES

# %%
plt.figure(dpi=150)
sns.scatterplot(data=all_sites,x='RottenTomatoes',y='RottenTomatoes_User')
plt.xlim(0,100)
plt.ylim(0,100)
# Out:
# (0.0, 100.0)

# %% [markdown]
# ##CREATE A NEW COLUMNS BASED OF THE DIFFERENCE BET CRITICS RATINGS AND USER RATINGS FOR ROTTEN TOMATOES

# %%
all_sites['Rotten_diff']=all_sites['RottenTomatoes']-all_sites['RottenTomatoes_User']

# %%
all_sites['Rotten_diff'].apply(abs).mean()
# Out:
# 15.095890410958905

# %%
sns.histplot(data=all_sites,x='Rotten_diff',kde=True,bins=25)

# %% [markdown]
# ##top 5movies users rated than critics on average

# %%
all_sites.nsmallest(5,'Rotten_diff')['FILM']
# Out:
# 3         Do You Believe? (2015)
# 85             Little Boy (2015)
# 105      Hitman: Agent 47 (2015)
# 134      The Longest Ride (2015)
# 125    The Wedding Ringer (2015)
# Name: FILM, dtype: object

# %%
all_sites.nlargest(5,'Rotten_diff')['FILM']
# Out:
# 69                    Mr. Turner (2014)
# 112                   It Follows (2015)
# 115            While We're Young (2015)
# 37                 Welcome to Me (2015)
# 40     I'll See You In My Dreams (2015)
# Name: FILM, dtype: object

# %% [markdown]
# #METACRITIC

# %%
plt.figure(figsize=(10,4),dpi=150)
sns.scatterplot(data=all_sites,x='Metacritic',y='Metacritic_User')
plt.xlim(0,100)
plt.ylim(0,10)
# Out:
# (0.0, 10.0)

# %% [markdown]
# ##IMDB

# %%
plt.figure(figsize=(10,4),dpi=150)
sns.scatterplot(data=all_sites,x='Metacritic_user_vote_count',y='IMDB_user_vote_count')

# %%
all_sites.nlargest(1,'Metacritic_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  ...  Fandango_Difference  Rotten_diff
# 88  Mad Max: Fury Road (2015)              97  ...                  0.2            9
#
# [1 rows x 23 columns]

# %%
all_sites.nlargest(1,'IMDB_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  ...  Fandango_Difference  Rotten_diff
# 14  The Imitation Game (2014)              90  ...                  0.4           -2
#
# [1 rows x 23 columns]

# %%
df_merge=pd.merge(df,all_sites,on='FILM',how='inner')
df_merge
# Out:
#                                    FILM  ...  Rotten_diff
# 0           Fifty Shades of Grey (2015)  ...          -17
# 1                 Jurassic World (2015)  ...          -10
# 2                American Sniper (2015)  ...          -13
# 3                      Furious 7 (2015)  ...           -3
# 4                     Inside Out (2015)  ...            8
# ..                                  ...  ...          ...
# 140  Kumiko, The Treasure Hunter (2015)  ...           24
# 141  The Diary of a Teenage Girl (2015)  ...           14
# 142            The Wrecking Crew (2015)  ...            9
# 143                    Tangerine (2015)  ...            9
# 144            Maps to the Stars (2015)  ...           14
#
# [145 rows x 27 columns]

# %% [markdown]
# ##NORAMLISE COLUMNS TO FANDANGO STARS AND RATINGS

# %%
df_merge.describe().transpose()['max']
# Out:
# STARS                              5.0
# RATING                             4.8
# VOTES                          34846.0
# RottenTomatoes                   100.0
# RottenTomatoes_User               94.0
# Metacritic                        94.0
# Metacritic_User                    9.6
# IMDB                               8.6
# Fandango_Stars                     5.0
# Fandango_Ratingvalue               4.8
# RT_norm                            5.0
# RT_user_norm                       4.7
# Metacritic_norm                    4.7
# Metacritic_user_nom                4.8
# IMDB_norm                          4.3
# RT_norm_round                      5.0
# RT_user_norm_round                 4.5
# Metacritic_norm_round              4.5
# Metacritic_user_norm_round         5.0
# IMDB_norm_round                    4.5
# Metacritic_user_vote_count      2375.0
# IMDB_user_vote_count          334164.0
# Fandango_votes                 34846.0
# Fandango_Difference                0.5
# ...

# %%
df_merge.columns
# Out:
# Index(['FILM', 'STARS', 'RATING', 'VOTES', 'YEAR', 'RottenTomatoes',
#        'RottenTomatoes_User', 'Metacritic', 'Metacritic_User', 'IMDB',
#        'Fandango_Stars', 'Fandango_Ratingvalue', 'RT_norm', 'RT_user_norm',
#        'Metacritic_norm', 'Metacritic_user_nom', 'IMDB_norm', 'RT_norm_round',
#        'RT_user_norm_round', 'Metacritic_norm_round',
#        'Metacritic_user_norm_round', 'IMDB_norm_round',
#        'Metacritic_user_vote_count', 'IMDB_user_vote_count', 'Fandango_votes',
#        'Fandango_Difference', 'Rotten_diff'],
#       dtype='object')

# %%
norm_scores=df_merge[['STARS','RATING','RT_norm','RT_user_norm','Metacritic_norm_round','Metacritic_user_norm_round', 'IMDB_norm_round']]

# %%
norm_scores.head()
# Out:
#    STARS  RATING  ...  Metacritic_user_norm_round  IMDB_norm_round
# 0    4.0     3.9  ...                         1.5              2.0
# 1    4.5     4.5  ...                         3.5              3.5
# 2    5.0     4.8  ...                         3.5              3.5
# 3    5.0     4.8  ...                         3.5              3.5
# 4    4.5     4.5  ...                         4.5              4.5
#
# [5 rows x 7 columns]

# %%
def move_legend(ax, new_loc, **kws):
    old_legend = ax.legend_
    handles = old_legend.legendHandles
    labels = [t.get_text() for t in old_legend.get_texts()]
    title = old_legend.get_title().get_text()
    ax.legend(handles, labels, loc=new_loc, title=title, **kws)

# %% [markdown]
# ##COMPARING DISTURBUTION OF SCORES ACROSS SITES

# %%
fig,ax=plt.subplots(figsize=(15,6),dpi=200)



sns.kdeplot(data=norm_scores,clip=[0,5],shade=True,palette='Set1')
move_legend(ax, "upper left")

# %% [markdown]
# ##WORST MOVIES RATED ACROSS ALL PLATFORMS

# %%
sns.clustermap(norm_scores,cmap='magma',col_cluster=False)

# %%
norm_scores.columns
# Out:
# Index(['STARS', 'RATING', 'RT_norm', 'RT_user_norm', 'Metacritic_norm_round',
#        'Metacritic_user_norm_round', 'IMDB_norm_round'],
#       dtype='object')

# %%
norm_films=df_merge[['FILM','STARS', 'RATING', 'RT_norm', 'RT_user_norm', 'Metacritic_norm_round',
       'Metacritic_user_norm_round', 'IMDB_norm_round']]

# %%
worst_films=norm_films.nsmallest(10,'RT_norm')
worst_films
# Out:
#                              FILM  ...  IMDB_norm_round
# 49  Paul Blart: Mall Cop 2 (2015)  ...              2.0
# 84        Hitman: Agent 47 (2015)  ...              3.0
# 54             Hot Pursuit (2015)  ...              2.5
# 25                 Taken 3 (2015)  ...              3.0
# 28          Fantastic Four (2015)  ...              2.0
# 50       The Boy Next Door (2015)  ...              2.5
# 87     Unfinished Business (2015)  ...              2.5
# 88                The Loft (2015)  ...              3.0
# 77             Seventh Son (2015)  ...              3.0
# 78               Mortdecai (2015)  ...              3.0
#
# [10 rows x 8 columns]

# %%
fig,ax=plt.subplots(figsize=(15,6),dpi=200)



sns.kdeplot(data=worst_films,clip=[0,5],shade=True,palette='Set1')
move_legend(ax, "upper left")
